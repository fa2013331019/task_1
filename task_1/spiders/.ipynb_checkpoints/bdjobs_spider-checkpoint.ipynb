# %%
# Settings for notebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Show Python version
import platform
platform.python_version()
# Out:
# '3.6.3'

# %% [markdown]
# # Import Scrapy

# %%
try:
    import scrapy
    #from scrapy_splash import SplashRequest
except:
    # !pip install scrapy
    import scrapy
from scrapy.crawler import CrawlerProcess

# %% [markdown]
# # Setting up a pipe line

# %%
import json

class JsonWriterPipeline(object):

    def open_spider(self, spider):
        self.file = open('result.jl', 'w')

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %% [markdown]
# # Creating the spider

# %%
import logging
from scrapy.utils.markup import remove_tags
from scrapy.spiders import CrawlSpider, Rule
from w3lib.html import replace_escape_chars
from scrapy.selector import HtmlXPathSelector
from scrapy.linkextractors import LinkExtractor
from scrapy.selector import Selector
from scrapy.http import HtmlResponse

class jobSpider(scrapy.Spider):
    name = "job"
    
    start_urls = ['http://jobs.bdjobs.com/jobdetails.asp?id=793245&fcatId=1&ln=1']
    
    for i in range(1000 , 9999):
        
        start_urls.append('http://jobs.bdjobs.com/jobdetails.asp?id=78' + str(i))
        start_urls.append('http://jobs.bdjobs.com/jobdetails.asp?id=79' + str(i))
    
    
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1}, # Used for pipeline 1
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': 'result.txt'                        # Used for pipeline 2
    }
    

    
    def parse(self, response):
        
        #links = response.css('div.job-title-text a::attr(href)').extract()
        para = response.xpath('//p')
        uls =  response.xpath('//ul')
        h4s =  response.xpath('//h4')
        
        if len(para) == 5 and len(uls) > 16 and len(h4s) > 7: 
            
            yield {   
            
            'Title': remove_tags(" ".join(response.xpath('//h4/text()').extract_first().split())),
                
            'Category': remove_tags(" ".join(response.xpath("//p/strong/following-sibling::text()").extract_first().split())),
            
            'Company Name': remove_tags(" ".join(response.xpath('//h2/text()').extract_first().split())),
            
            'Vacancy': remove_tags(" ".join(para[1].extract().split())),
                
            'Job Responsibility': remove_tags(" ".join(response.xpath("//div[@class='job_des']/h5/following-sibling::ul/li/text()").extract_first().split())),
                
            'Employment Status': remove_tags(" ".join(para[2].extract().split())),
                
            'Educational Requirement': remove_tags(" ".join(response.xpath("//div[@class='edu_req']/h5/following-sibling::ul/li/text()").extract_first().split())),
                
            'Additional Requirement': remove_tags(" ".join(response.xpath("//div[@class='job_req']/h5/following-sibling::ul/li/text()").extract_first().split())),
                
            'Job Location': remove_tags(" ".join(para[3].extract().split())),
                
            'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
            
            'Job Source': remove_tags(" ".join(para[4].extract().split())),
            
            'Application Deadline': remove_tags(" ".join(response.xpath("//span[@class='date']/text()/following-sibling::strong/text()").extract_first().split())),  
            }

class linkSpider(scrapy.Spider):
    
    name = "links"
    
    start_urls = ['http://jobs.bdjobs.com/jobsearch.asp',]
    
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1}, # Used for pipeline 1
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': 'links.txt'                        # Used for pipeline 2
    }
   
    
    def parse(self, response):
        
        yield {
            'url' : response.css('div.job-title-text a::attr(href)').extract()
        }
        next_page = response.css('li.prevnext a::attr(href)').extract_first()
        if next_page is not None:
            yield response.follow(next_page, callback=self.parse)

# %% [markdown]
# # Start Crawler

# %%
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

process.crawl(jobSpider)
process.start()
#process.end()
# Out:
# 2018-09-26 19:15:44 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-09-26 19:15:44 [scrapy.utils.log] INFO: Versions: lxml 4.1.0.0, libxml2 2.9.4, cssselect 1.0.3, parsel 1.5.0, w3lib 1.19.0, Twisted 18.7.0, Python 3.6.3 |Anaconda, Inc.| (default, Oct 13 2017, 12:02:49) - [GCC 7.2.0], pyOpenSSL 17.2.0 (OpenSSL 1.0.2l  25 May 2017), cryptography 2.0.3, Platform Linux-4.10.0-38-generic-x86_64-with-debian-stretch-sid
# 2018-09-26 19:15:44 [scrapy.crawler] INFO: Overridden settings: {'FEED_FORMAT': 'json', 'FEED_URI': 'result.txt', 'LOG_LEVEL': 30, 'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2018-09-26 19:16:00 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791050> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:16:11 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791089> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:16:11 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791092> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:16:12 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791095> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:16:12 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791097> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:16:19 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791126> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 45, in parse
#     'Company Name': remove_tags(" ".join(response.xpath('//h2/text()').extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:16:20 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791130> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:16:22 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791135> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 45, in parse
#     'Company Name': remove_tags(" ".join(response.xpath('//h2/text()').extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:16:34 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791184> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:16:49 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791242> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:16:52 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791256> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:16:55 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791274> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:04 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791307> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:05 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791308> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:05 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791309> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:05 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791311> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:06 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791313> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:09 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791329> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 45, in parse
#     'Company Name': remove_tags(" ".join(response.xpath('//h2/text()').extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:10 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791337> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:10 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791339> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:11 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791341> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:12 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791335> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:12 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791340> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:15 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791354> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:17 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791363> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:18 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791366> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:19 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791369> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:19 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791372> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:30 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791394> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:34 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791408> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:35 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791416> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:36 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791418> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:38 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791428> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:41 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791438> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:42 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791439> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:43 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791446> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:46 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791459> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:51 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791479> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:17:53 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=791489> (referer: None)
# Traceback (most recent call last):
# ...
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:25:11 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793104> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:25:13 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793108> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:25:15 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793109> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:25:30 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793156> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 45, in parse
#     'Company Name': remove_tags(" ".join(response.xpath('//h2/text()').extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:25:45 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793217> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:25:49 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793233> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:26:06 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793295> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:26:07 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793303> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:26:08 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793305> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:26:13 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793321> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:26:17 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793341> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'
# 2018-09-26 19:26:18 [scrapy.core.scraper] ERROR: Spider error processing <GET http://jobs.bdjobs.com/jobdetails.asp?id=793345> (referer: None)
# Traceback (most recent call last):
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/home/tensor_cs/anaconda3/lib/python3.6/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-4-c490cdf2450d>", line 59, in parse
#     'Salary': remove_tags(" ".join(response.xpath("//div[@class='salary_range']/h5/following-sibling::ul/text()").extract_first().split())),
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
ll result.*
# Out:
# -rw-rw-r-- 1 tensor_cs     379 Sep 26 19:10 result.jl
# -rw-rw-r-- 1 tensor_cs 1854970 Sep 26 19:10 result.txt

# %%
# !tail -n 2 result.jl
# Out:
# {"Title": "Assistant Supervisor/ Supervisor- Finance", "Category": "Accounting/Finance", "Company Name": "Intertek Bangladesh", "Vacancy": " 02 ", "Employment Status": "Full-time", "Educational Requirement": "Bachelor of Commerce (BCom)", "Job Location": "Dhaka", "Salary": "Negotiable", "Job Source": "Bdjobs.com Online Job Posting", "Application Deadline": "October 26, 2018"}

# %%
# !tail -n 2 result.txt
# Out:
# {"Title": "AGM Assistant (Production)", "Company Name": "Milanty Ltd.", "Vacancy": " 01 ", "Job Context": " B.Sc. in Textile Engineering or B.Sc. in Industrial and Production Engineering. ", "Employment Status": "Full-time", "Job Location": "Narayanganj", "Job Source": "Bdjobs.com Online Job Posting", "Class": "Category: Garments/Textile"}
# ]
